# %% [markdown]
# ## 1. Familiarización con el lenguaje Python
# #### Objetivos del notebook.
# - Objetivo 1: Familiarizarse con la sintaxis del lenguaje Python
# - Objetivo 2: Conocer funciones simples de Python
# - Dataset: No se requieren ningún archivo adicional

# %% [markdown]
# ##### Ejercicicio 1.1. Tu primer celda de código

# %%
# La función print() sirve para mostrar mensajes
print("Hola Mundo")
print("Este notebook es lo mejor")
print("Aprenderé a automatizar tareas")
print("Nunca olvides que las cadenas van en comillas")
print("Python permite usar dos tipos de comillas: dobles o simples")
# Out:
# Hola Mundo
# Este notebook es lo mejor
# Aprenderé a automatizar tareas
# Nunca olvides que las cadenas van en comillas
# Python permite usar dos tipos de comillas: dobles o simples

# %%
# Saltos de línea de código usando print()
print("Esta es la línea 1\nEsta es la línea 2\nEsta es la línea 3")
# Out:
# Esta es la línea 1
# Esta es la línea 2
# Esta es la línea 3

# %%
# La función print() es tu principal herramienta para mostrar información.
# Imagina que estás creando una interfaz para mostrar información de un curso.

# Usamos print() para dar la bienvenida y mostrar los detalles.
print("=========================================================")
print("   ¡Bienvenido/a al Taller de Fundamentos de Python!  ")
print("=========================================================")
print("\nDetalles del taller: \n")
print("- Evento: Taller de Programación para principiantes")
print("- Fecha: 25 de Octubre de 2025")
print("- Objetivo: Aprender la sintaxis básica de Python para crear programas sencillo")
print("\n¡Esperamos que disfrutes el aprendizaje!")
# Out:
# ...
#    ¡Bienvenido/a al Taller de Fundamentos de Python!
# ...
#
# Detalles del taller:
#
# - Evento: Taller de Programación para principiantes
# - Fecha: 25 de Octubre de 2025
# - Objetivo: Aprender la sintaxis básica de Python para crear programas sencillo
#
# ¡Esperamos que disfrutes el aprendizaje!

# %% [markdown]
# ## 2. Tipos de variables
# #### Objetivos del notebook.
# - Objetivo 1: Familiarizarse con el uso de variables el Python
# - Objetivo 2: Conocer los tipos de variables que Python maneja
# - Dataset: No se requieren ningún archivo adicional

# %%
# Las variables permiten guardar información y usarla después
# Cada variable puede ser de un tipo distinto
# Supongamos que queremos crear un perfil de un usuario

# str (string): Para guardar el nombre del usuario
nombre_usuario = "Peter Parker"

# int (integer): Para números enteros, como la edad o el ID
edad = 28
id_usuario = 101

# float (flotante): Para números decimales. Como una calificación o el balance de cuenta
calificacion_promedio = 9.5
balance_banco = 1202.2

# bool (booleano): Para valores verdaero (True) o Falso (False)
cliente_premium = True
auto = False

# Ahora podemos combinar la función print() y las variables para mostrar la información
print("--- Información del usuario ---\n")
print("Nombre: ", nombre_usuario)
print("Edad: ", edad)
print("Calificación: ", calificacion_promedio)
print("¿Es cliente premium?:", cliente_premium)
print("¿Cuenta con automóvil?:", auto)
print("\n-------------------------------")
# Out:
# --- Información del usuario ---
#
# Nombre:  Peter Parker
# Edad:  28
# Calificación:  9.5
# ¿Es cliente premium?: True
# ¿Cuenta con automóvil?: False
#
# -------------------------------

# %% [markdown]
# ## 3. Operadores matemáticos y concatenación
# #### Objetivos del notebook.
# - Objetivo 1: Conocer los tipos de operadores en Python
# - Objetivo 2: Realizar operaciones con operadores y concatenaciones
# - Dataset: No se requieren ningún archivo adicional

# %%
# Python también permite el uso de operadores matemáticos
# Puede funcionar como una calculadora
# Vamos a simular el cálculo total de una compra.

# Definir la fecha de compra
fecha_compra = "04/11/2025"

# Precios de productos
precio_cafe = 75
precio_pan = 20

# Cantidad de productos
cantidad_cafe = 2
cantidad_pan = 4

# Calcular subtotal
subtotal_cafe = precio_cafe * cantidad_cafe
subtotal_pan = precio_pan * cantidad_pan

# Calculamos el total de la compra
total_compra = subtotal_cafe + subtotal_pan

# Realizamos un resumen de la compra
print("--- Resumen de compra ---\n")
print("Fecha de compra:", fecha_compra)
print("Subtotal café:", subtotal_cafe)
print("Subtotal pan:", subtotal_pan)
print("Total:", total_compra)

# El operador de suma puede usarse para concatenar cadena
# Vamos a mostrar el ejemplo con los datos anteriores
# Vamos a definir un nombre de usuario
nombre_usuario = "Carlos"
mensaje_bienvenida = "Hola, "

# Concatenamos el mensaje completo
mensaje_completo = mensaje_bienvenida + nombre_usuario + ". Gracias por tu compra."
print("\nMensaje para el cliente")
print(mensaje_completo)
# Out:
# --- Resumen de compra ---
#
# Fecha de compra: 04/11/2025
# Subtotal café: 150
# Subtotal pan: 80
# Total: 230
#
# Mensaje para el cliente
# Hola, Carlos. Gracias por tu compra.

# %% [markdown]
# ## 4. Conversión a tipos de datos
# #### Objetivos del notebook.
# - Objetivo 1: Emplear funciones built-in para cambiar el tipo de datos
# - Objetivo 2: Realizar operaciones con diferentes tipos de datos
# - Dataset: No se requieren ningún archivo adicional

# %%
# Es necesario tener en cuenta que algunas funciones en Python 
# emplean un tipo de dato específico, y a veces es necesario 
# cambiarlo como en el caso con la función input()

# La función input() siempre devuelve el valor com texto (str)
año_de_nacimiento = input("Escribe tu año de nacimiento: ")
print("El tipo de dato que nos dio input() fue: \n", type(año_de_nacimiento))

# Al intentar restar o hacer operaciones con esta variable, obtendremos error
# Vamos a calcular la edad aproximada
# edad_aprox = 2025 - año_de_nacimiento

# --- Conversion de tipos (Casting) ---
# Empleamos la función int() para pasar de texto a valor numérico
año_de_nacimiento = int(input("Escribe tu año de nacimiento: "))
print("\nEl tipo de dato que nos dio int(input()) fue: \n", type(año_de_nacimiento))

# Ahora sí podemos realizar operaciones
año_actual = 2025
edad_aprox = año_actual - año_de_nacimiento

# Mostramos el resultado
print("\nTu edad aproximada es: ", edad_aprox, "años.")
# Out:
# El tipo de dato que nos dio input() fue:
#  <class 'str'>
#
# El tipo de dato que nos dio int(input()) fue:
#  <class 'int'>
#
# Tu edad aproximada es:  -15 años.

# %%
# Out:
# -----------------------------------------
#         Reporte de Inventario
# -----------------------------------------
# Producto:           Headphones
# Cantidad en Stock:  15 unidades
# Precio Unitario:    $2500.50 MXN
# ¿Está en oferta?:   True
# -----------------------------------------
#
#
# -----------------------------------------
#         Reporte de Inventario
# -----------------------------------------
# Producto:           Headphones
# Cantidad en Stock:  15 unidades
# Precio Unitario:    $2500.50 MXN
# ¿Está en oferta?:   True
# -----------------------------------------
# Valor total del inventario: $37507.50 MXN
# Cesar Antonio

# %% [markdown]
# ## 5. Formateo de cadenas (F-strings)
# #### Objetivos del notebook.
# - Objetivo 1: Generar outputs de cadenas personalizados
# - Objetivo 2: Combinar tipos de datos, operadores matemáticos y concatenaciones para formatear outputs
# - Dataset: No se requieren ningún archivo adicional

# %%
# Las F-strings (cadenas formateadas) son la mejor manera de mezclar texto y variables.
# Son más limpias y fáciles de leer que la concatenación con '+'.

# Información de un producto
nombre_producto = "Headphones"
cantidad_stock = 15
precio_unitario = 2500.50
en_oferta = True

# --- Creando un reporte con F-strings ---
# Simplemente pon una 'f' antes de las comillas y escribe tus variables entre llaves {}.
reporte = f"""
-----------------------------------------
        Reporte de Inventario
-----------------------------------------
Producto:           {nombre_producto}
Cantidad en Stock:  {cantidad_stock} unidades
Precio Unitario:    ${precio_unitario:.2f} MXN
¿Está en oferta?:   {en_oferta}
-----------------------------------------
"""

# Mostramos el reporte con print()
print(reporte)

# Es posible incluso realizar operaciones aritméticas en la F-strings
# Vamos determinar el valor total 
valor_total = cantidad_stock * precio_unitario
reporte += f"Valor total del inventario: ${valor_total:.2f} MXN"
print(reporte)

# %%
# --- Simulador de Presupuesto Mensual ---

# ** STRINGS (str) **: Almacenan texto para personalizar la experiencia.
nombre_usuario = "Alex"
mes = "Octubre"

# ** INTEGERS (int) **: Se usan para contar cosas, como los días.
dias_del_mes = 31

# ** FLOATS (float) **: Perfectos para dinero, ya que manejan decimales.
ingreso_mensual = 18500.50
gasto_renta = 7500.00
gasto_comida = 4250.75
gasto_transporte = 980.25
ahorro_adicional = 1200.00

# ** BOOLEAN (bool) **: Para registrar un estado de sí o no.
meta_ahorro_alcanzada = False # Aún no lo sabemos, lo calcularemos.

# --- CÁLCULOS Y LÓGICA ---

# Sumamos todos los gastos para obtener un total.
total_gastos = gasto_renta + gasto_comida + gasto_transporte

# Calculamos el dinero que queda después de gastos.
flujo_libre = ingreso_mensual - total_gastos

# Calculamos el ahorro final del mes.
ahorro_final = flujo_libre - ahorro_adicional

# Calculamos el promedio de gasto diario.
gasto_diario_promedio = total_gastos / dias_del_mes

# Verificamos si el ahorro final es mayor a $5,000 (nuestra meta).
if ahorro_final > 5000:
    meta_ahorro_alcanzada = True

# --- REPORTE FINAL ---
# Usamos print() con f-strings para crear un reporte financiero detallado y fácil de leer.
# La sintaxis {:.2f} formatea los números para que siempre muestren 2 decimales.
print("=====================================================")
print(f"      Reporte Financiero para {nombre_usuario} - Mes: {mes}")
print("=====================================================")
print(f"Ingreso Mensual Total:      ${ingreso_mensual:.2f} MXN")
print("-----------------------------------------------------")
print("Desglose de Gastos:")
print(f"  - Renta:                  ${gasto_renta:.2f} MXN")
print(f"  - Comida:                 ${gasto_comida:.2f} MXN")
print(f"  - Transporte:             ${gasto_transporte:.2f} MXN")
print(f"Total de Gastos Fijos:      ${total_gastos:.2f} MXN")
print("-----------------------------------------------------")
print(f"Flujo de Dinero Libre:      ${flujo_libre:.2f} MXN")
print(f"Ahorro Adicional Planeado:  ${ahorro_adicional:.2f} MXN")
print(f"Ahorro Final Real del Mes:  ${ahorro_final:.2f} MXN")
print("=====================================================")
print(f"Análisis Adicional:")
print(f"  - Gasto Diario Promedio:  ${gasto_diario_promedio:.2f} MXN")
print(f"  - ¿Se cumplió la meta de ahorro de $5,000?: {meta_ahorro_alcanzada}")
print("=====================================================")
# Out:
# ...
#       Reporte Financiero para Alex - Mes: Octubre
# ...
# Ingreso Mensual Total:      $18500.50 MXN
# -----------------------------------------------------
# Desglose de Gastos:
#   - Renta:                  $7500.00 MXN
#   - Comida:                 $4250.75 MXN
#   - Transporte:             $980.25 MXN
# Total de Gastos Fijos:      $12731.00 MXN
# -----------------------------------------------------
# Flujo de Dinero Libre:      $5769.50 MXN
# Ahorro Adicional Planeado:  $1200.00 MXN
# Ahorro Final Real del Mes:  $4569.50 MXN
# ...
# Análisis Adicional:
#   - Gasto Diario Promedio:  $410.68 MXN
#   - ¿Se cumplió la meta de ahorro de $5,000?: False
# ...
